# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

x = np.linspace(5,100,100)
y = np.linspace(10,1000,100)

plt.plot(x,y)

# %%
plt.show()

# %%
plt.plot([1,4,6,8],[3,2,3,6])
plt.show()
